# %%
import sys
sys.path.append('../script/')
from prepare_data import DataPreparationTrain
from results_visualisation import ResultsEvaluation, ResultsVisualisation, EvalWithoutScaling, SaveTest

import ultralytics
ultralytics.checks()
from ultralytics import YOLO
# Out:
# Ultralytics YOLOv8.0.207 🚀 Python-3.10.12 torch-2.1.0 CPU (Apple M1)
# Setup complete ✅ (8 CPUs, 8.0 GB RAM, 237.8/460.4 GB disk)

# %%
path_weights = "../trained_models/weights2/best.pt"
model = YOLO(path_weights)

# %%
path_images_test = "../data/test/"
results=model.predict(source=path_images_test,conf=0.4, save = True, project = "../logs")
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# image 1/1543 /Users/damidoum/Desktop/Data_challenge/notebooks/../data/test/1000013824.jpg: 352x640 1 Car, 103.2ms
# image 2/1543 /Users/damidoum/Desktop/Data_challenge/notebooks/../data/test/1000079360.jpg: 480x640 1 Car, 144.7ms
# image 3/1543 /Users/damidoum/Desktop/Data_challenge/notebooks/../data/test/1001848832.jpg: 448x640 1 Car, 148.3ms
# ...

# %%
save_test = SaveTest(results)

# %%
df_results = save_test.get_results_as_dataframe()[["im_name","x_min","y_min","x_max","y_max"]]
df_results
# Out:
#              im_name       x_min       y_min        x_max        y_max
# 0     1000013824.jpg   16.821707   67.535187   624.199829   305.406006
# 1     1000079360.jpg   17.238007   35.898254   553.476562   414.697754
# 2     1001848832.jpg   85.996254  150.875687  1581.305176  1101.743530
# 3     1002635264.jpg   38.114044   95.600670   430.676056   275.170807
# 4     1003880448.jpg    1.576753   78.801926   446.846985   278.119843
# ...              ...         ...         ...          ...          ...
# 1538   993787904.jpg  170.845612   32.366943   895.456360   689.166382
# 1539   994312192.jpg  195.450516   45.532341   800.000000   457.022125
# 1540   994377728.jpg  150.263245   75.597595   500.639038   405.589111
# 1541    99910592.jpg    0.000000    0.000000     0.000000     0.000000
# 1542   999751680.jpg   53.700333   30.239468   341.186218   237.635910
#
# [1543 rows x 5 columns]
